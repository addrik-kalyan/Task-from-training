# %%
num = int(input("Enter a number: "))

num += 5
print("After += 5:", num)
num -= 3
print("After -= 3:", num)
num *= 2
print("After *= 2:", num)
num /= 4
print("After /= 4:", num)
num %= 3
print("After %= 3:", num)

# %%
name = "Abi"
age_21 = 21
_studentMark = 90

# %%
data = {
    "name": "Abi",
    "age": 21,
    "marks": [85, 90],
    "pass": True,
    "grade": None
}

for k in data:
    print(type(data[k]))

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a > b:
    print("First number is greater")
elif b > a:
    print("Second number is greater")
else:
    print("Both are equal")

print("Both positive:", a > 0 and b > 0)
print("At least one even:", a % 2 == 0 or b % 2 == 0)
